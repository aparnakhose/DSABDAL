# %%
name="aparna khose"
mailingaddress="kalewadi pune 17"
print(f"my name is :{name}  and my mailingaddress is:{mailingaddress}")
# Out:
# my name is :aparna khose  and my mailingaddress is:kalewadi pune 17

# %%
name=input("enter your name ")
print(f"hello guys {name}")

# %%
width = float(input("Enter the widht of the room in feet :"))
height = float(input("Enter the height the room in feet :"))
print(f"the width of the room is :{width} and the height of the room is :{height}")
# Out:
# Enter the widht of the room in feet : 77
# ,Enter the height the room in feet : 89.70
# the width of the room is :77.0 and the height of the room is :89.7

# %%
x=input()
print ( your name is .format{x}
# Out:
#   Cell In[1], line 2
#     print ( your name is .format{x}
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x=input()
print ("your name is {}".format(x))
# Out:
#  aparna khose
# your name is aparna khose

# %%
width = float(input("enter the width of the room :"))
height =float(input("enter the height of the room :"))
area = width*height
print("the area of the room in square feet is : ", area)
# Out:
# enter the width of the room : 6500
# enter the height of the room : 6000
# the area of the room in square feet is :  39000000.0

# %%
a = int (input("Enter the value of a :"))
b = int (input("Enter the value of b :"))
c = int (input("Enter the value of c :"))
print (a, "+", b, "-",c, "is",a+b-c)
# Out:
# Enter the value of a : 10
# Enter the value of b : 20
# Enter the value of c : 10
# 10 + 20 - 10 is 20
